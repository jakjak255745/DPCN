# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#task 2

def infection_simulation(G: nx.Graph, p: float, source: int):
    """
    
    
    
    
    """
    #setting all nodes as susceptible
    states={node:0 for node in G.nodes()}
    nx.set_node_attributes(G,states,"state")
    source=list(G.nodes())[source]
    G.nodes[source]['state']=1
    infects=[]
    step=0
    #step_graphs=[] #list of graphs at each MCS
    
    while True: #loop if there are still infected people
        #step_graphs.append(G)
        curr_states=nx.get_node_attributes(G, "state")
        
        infected = [x for x,y in G.nodes(data=True) if y['state']==1] # take all the infected nodes
        infects.append((step,len(infected)))
        for i in infected:
            
            targets=nx.neighbors(G,i) #targets that the infection can spread to
            for t in targets:

                prob=np.random.uniform()
                if prob<p and G.nodes[t]['state']==0:
                    G.nodes[t]['state']=1
                    
            G.nodes[i]['state']=-1

        if 1 not in curr_states.values(): # if no infected remain break the loop
            break
        step+=1
    return infects

# %%
sim_A1=infection_simulation(A1,0.2,0)

# %%
#A square lattice
A1=nx.grid_2d_graph(10,10)
#B random graph
B1=nx.gnp_random_graph(100,0.5)
#C 
C1=nx.watts_strogatz_graph(100,3,0.5)
#D
D1=nx.barabasi_albert_graph(100,3)

# %%
# SQUARE LATTICE
#p=0.2
res1={}
for i in range(100):    
    sim_A1=infection_simulation(A1,0.2,0)
    for step in sim_A1:
        if step[0] in res1:
            res1[step[0]]+=step[1]
        else:
            res1[step[0]]=step[1]
res1_avg = [i/100 for i in res1.values()]
#print(res1_avg)




#p=0.5
res2={}
for i in range(100):    
    sim_A2=infection_simulation(A1,0.5,0)
    for step in sim_A2:
        if step[0] in res2:
            res2[step[0]]+=step[1]
        else:
            res2[step[0]]=step[1]
res2_avg = [i/100 for i in res2.values()]
#print(res2_avg)

#p=0.9
res3={}
for i in range(100):    
    sim_A3=infection_simulation(A1,0.9,0)
    for step in sim_A3:
        if step[0] in res3:
            res3[step[0]]+=step[1]
        else:
            res3[step[0]]=step[1]
res3_avg = [i/100 for i in res3.values()]
#print(res3_avg)
# Out:
# [1.0, 1.13, 1.13, 1.26, 1.37, 1.35, 1.24, 1.31, 1.36, 1.37, 1.4, 1.32, 1.29, 1.23, 1.1, 0.93, 0.76, 0.59, 0.48, 0.37, 0.27, 0.22, 0.21, 0.21, 0.14, 0.12, 0.06, 0.02, 0.02, 0.03, 0.04, 0.04, 0.02, 0.0]

# %%
# RANDOM GRAPH
#p=0.2
res1={}
for i in range(100):    
    sim_B1=infection_simulation(B1,0.2,0)
    for step in sim_B1:
        if step[0] in res1:
            res1[step[0]]+=step[1]
        else:
            res1[step[0]]=step[1]
res1_avg = [i/100 for i in res1.values()]
#print(res1_avg)




#p=0.5
res2={}
for i in range(100):    
    sim_B2=infection_simulation(B1,0.5,0)
    for step in sim_B2:
        if step[0] in res2:
            res2[step[0]]+=step[1]
        else:
            res2[step[0]]=step[1]
res2_avg = [i/100 for i in res2.values()]
#print(res2_avg)

#p=0.9
res3={}
for i in range(100):    
    sim_B3=infection_simulation(B1,0.9,0)
    for step in sim_B3:
        if step[0] in res3:
            res3[step[0]]+=step[1]
        else:
            res3[step[0]]=step[1]
res3_avg = [i/100 for i in res3.values()]
#print(res3_avg)

# %%
# WATTS-STROGATZ
#p=0.2
res1={}
for i in range(100):    
    sim_C1=infection_simulation(C1,0.2,0)
    for step in sim_C1:
        if step[0] in res1:
            res1[step[0]]+=step[1]
        else:
            res1[step[0]]=step[1]
res1_avg = [i/100 for i in res1.values()]
#print(res1_avg)




#p=0.5
res2={}
for i in range(100):    
    sim_C2=infection_simulation(C1,0.5,0)
    for step in sim_C2:
        if step[0] in res2:
            res2[step[0]]+=step[1]
        else:
            res2[step[0]]=step[1]
res2_avg = [i/100 for i in res2.values()]
#print(res2_avg)

#p=0.9
res3={}
for i in range(100):    
    sim_C3=infection_simulation(C1,0.9,0)
    for step in sim_C3:
        if step[0] in res3:
            res3[step[0]]+=step[1]
        else:
            res3[step[0]]=step[1]
res3_avg = [i/100 for i in res3.values()]

# %%
# BARABASSI-ALBERT
#p=0.2
res1={}
for i in range(100):    
    sim_D1=infection_simulation(D1,0.2,0)
    for step in sim_D1:
        if step[0] in res1:
            res1[step[0]]+=step[1]
        else:
            res1[step[0]]=step[1]
res1_avg = [i/100 for i in res1.values()]
#print(res1_avg)

#p=0.5
res2={}
for i in range(100):    
    sim_D2=infection_simulation(D1,0.5,0)
    for step in sim_D2:
        if step[0] in res2:
            res2[step[0]]+=step[1]
        else:
            res2[step[0]]=step[1]
res2_avg = [i/100 for i in res2.values()]
#print(res2_avg)

#p=0.9
res3={}
for i in range(100):    
    sim_D3=infection_simulation(D1,0.9,0)
    for step in sim_D3:
        if step[0] in res3:
            res3[step[0]]+=step[1]
        else:
            res3[step[0]]=step[1]
res3_avg = [i/100 for i in res3.values()]

# %%
def draw_sims(L: list):
    #https://www.youtube.com/watch?v=SiXjTkGFwng

    for g in L:
        color_map=nx.get_node_attributes(g)
        for key in color_map:
            if color_map[key]==1:
                color_map[key]='blue'
            elif color_map[key]==0:
                color_map[key]='red'
            elif color_map[key]==0:
                color_map[key]='green'
        node_colors=[color_map.get(node) for node in g.nodes()]
        nx.draw(g, node_colors=node_colors)
        plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2be72a1a-6ede-4702-bb85-1f84486961ea' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
